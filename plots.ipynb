# %%
import main
import time
import matplotlib.pyplot as plt
import numpy as np
import run_strands

test = run_strands.TestClass()
test.test()

labels = ["Word Rules", "Greedy", "Dictionary"]
values = [test.wordy_time, test.greedy_time, test.dict_time]
fig = plt.figure(figsize = (10, 5))
plt.barh(labels, values, color='#f8cd05ff')
plt.ylabel("Algorithm")
plt.xlabel("Seconds elapsed")
plt.title("Efficiency of different solving algorithms")
plt.show()

values2 = [test.wordy_solver.recursion_count, test.dfs_solver.recursion_count, test.dict_solver.recursion_count]
fig2 = plt.figure(figsize = (10, 5))
plt.barh(labels, values2, color='#c0ddd9ff')
plt.ylabel("Algorithm")
plt.xlabel("Times recursed")
plt.title("Efficiency of different solving algorithms")
plt.show()

values3 = [test.wordy_solver.incorrect_guesses, test.dfs_solver.incorrect_guesses, test.dict_solver.incorrect_guesses]
fig3 = plt.figure(figsize = (10, 5))
plt.barh(labels, values3, color='#aedfeeff')
plt.ylabel("Algorithm")
plt.xlabel("Incorrect Guesses")
plt.title("Efficiency of different solving algorithms")
plt.show()
# Out:
# WORD_RULES SOLVER
#
# Current Board:
# -------------------------
# | P | O | O | R | S | K |
# _________________________
# | K | S | N | E | W | E |
# _________________________
# | R | O | F | S | P | R |
# _________________________
# | U | T | E | N | O | K |
# _________________________
# | H | C | S | I | L | S |
# _________________________
# | O | S | T | O | E | K |
# _________________________
# | P | K | C | N | F | N |
# _________________________
# | S | T | I | G | S | I |
# _________________________
# I found solution 1! Path: [4, 5, 11, 10, 9, 3]
# I found solution 2! Path: [7, 0, 1, 2, 8]
# I found solution 3! Path: [14, 13, 12, 6]
# I found solution 4! Path: [15, 16, 22, 17, 23]
# I found solution 5! Path: [18, 19, 20, 21, 26, 27, 28, 29]
# I found solution 6! Path: [25, 24, 30, 36, 42, 43, 44, 38, 37, 31]
# I found solution 7! Path: [32, 33, 39, 45, 46]
# I found solution 8! Path: [35, 41, 47, 40, 34]
# You are done!
# You solved the puzzle! Good job!
# GREEDY SOLVER
#
# ...
